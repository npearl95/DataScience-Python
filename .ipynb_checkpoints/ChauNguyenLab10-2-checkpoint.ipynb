# %% [markdown]
# ## Lab 10, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 20 epochs are required before the generated text
# starts sounding coherent.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 200285
# Vectorization...

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ### Training (reduce the number of epochs, it takes a lot of time!!)
# -  Each epoch takes 5-10 minutes or so on a CPU (an epoch took 7.5 minutes for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let that puppy run for a while (2-3 hours)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=25,
          callbacks=[print_callback])
# Out:
# Epoch 1/25
# 200285/200285 [==============================] - 256s 1ms/step - loss: 1.9867
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ook of grace,
# still appeals more to his "
# ook of grace,
# still appeals more to his of the presponsity and the precess of the presporing and enterations and the power the sense that the sens and ever the sense of the self were the personation of the self--and the self--and the consiment of the may a so the prope and in the may and sension of the personations and and the properations and his and in the propo and in the interped and his new which the may a power and the sens and th
# ----- diversity: 0.5
# ----- Generating with seed: "ook of grace,
# still appeals more to his "
# ook of grace,
# still appeals more to his and from the endable and with the supmes there in the still at the may of a philosophers and a become the self were were this knowledge in the man in the other in a the most a for of the and become and influction of the instinction. and being there is the past the well propon in the what the conception of heart of seally and so might, and eart, and are feen in the preperione
# stare sense! ever the
# ----- diversity: 1.0
# ----- Generating with seed: "ook of grace,
# still appeals more to his "
# ook of grace,
# still appeals more to his my tous but evid to so mamality have in tham dew, as sistoughtraking the dresw es any power! that which the reginepable many--the
# makin dyppes
# scienct of whech wuthes be possic at but the
# phopoptiatiris to be awrimis of commet that asse; the more mode for "any inthirsivity and of, one suppeint and as faiteoursa: in suffer oo beod
# !
# ?be9  than etrerfilly."--s sub, which deconcections, belien of fol
# ----- diversity: 1.2
# ----- Generating with seed: "ook of grace,
# still appeals more to his "
# ook of grace,
# still appeals more to his certaanily things fuechable do we
# "cloman
# hatticy ael thind
# plizity,
# what the powly wast at the than--gamest, thule mitter--d. my evanh wife havd be who
# conseducts of aus of clupsive the abogeter, and just ladc, alway oldriom
# .
# lickeed
# herss mithess
# them take ta-ems in
#  gembleps as hows we have pence of peorlays, fence-it,
# the inderverative invery, dogaganional".. that he
# more mein so man'oricimn-
# Epoch 2/25
# 200285/200285 [==============================] - 244s 1ms/step - loss: 1.6345
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: ""saint" and "friend") the
# significance o"
# "saint" and "friend") the
# significance of the still to the still to the strength in the still to the restimate of the stand to the stands in the still to the moral of the strength of the strength of the precisely and the presime to the conduct of the strength of the stands there is not that the stands to the still to the powerful to the stand and such a still to the strength of the still to the strength of the strength of the pretinct o
# ----- diversity: 0.5
# ----- Generating with seed: ""saint" and "friend") the
# significance o"
# "saint" and "friend") the
# significance of the conderst and the corpasion of be to the constituted the moral for your of the elove that the forth of which we always with this sheove, there as a storther to the same ristince still, the sense and scholes of the conditionally one stall part in the word and the philosophers
#  life is the consident how may as a men in means of the for a presportion of the certain to the still as the restrion
# ----- diversity: 1.0
# ----- Generating with seed: ""saint" and "friend") the
# significance o"
# "saint" and "friend") the
# significance originantbling teration, its have not toless consequection, morrary it stantt willush mety,
# "that confluent 3yen for thes. everything slespection basitted in indefind like destronisity, should we may-meak to ksolute
# so contrush
# saspury to mere that which ther man furtley mure breas
# it is it is segainst, beisositive always withiung gone" too all mover to simitivat the on
# awighter bettis natrus fur
# ----- diversity: 1.2
# ----- Generating with seed: ""saint" and "friend") the
# significance o"
# "saint" and "friend") the
# significance only menagrine
# in virtuent "mesaors i reworge. stitle
# no re-athing," that
# mean
# simpows of justly as a tinuts one"s, ewimianive, with axcedict noal the honomently timate,
# as tostaming "midd ud been "bein is
# ther ule, avay for think hild i never that pathalisomion opent, as yet so the evt, lave condugabe ro! amber of those.. one" ilseptionally mores inceytes always of over consupernities, i toul thos
# Epoch 3/25
# 200285/200285 [==============================] - 264s 1ms/step - loss: 1.5447
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "of life for example, that the certain is"
# of life for example, that the certain is a something of the properst of the spiritual of the spiritual of the same also the same and and in the so free something of the soul in the spiritual of the species and and and and as a stronged to the stands the same also the desire of the side of the species and the spiritualists of the stricting of the spiritual despross of the so a same also and so in the spiritual in the soul of the subjecti
# ----- diversity: 0.5
# ----- Generating with seed: "of life for example, that the certain is"
# of life for example, that the certain is become but no in the fact that the spiritual standing a desire or things of all the solited our symporton of the percented by the spiritualist in the spirits of the percession of the night to ones under the philosophers and his propulses of our desprise? in the spiritualients of the senses in which he is a philosophers the species and in the conscience of its not of develops of the senses the pla
# ----- diversity: 1.0
# ----- Generating with seed: "of life for example, that the certain is"
# of life for example, that the certain is
# apploistf-themselves.
#
# hest innuntical ainghter apparain purisating i
# sails its dreagus, and laws and
# encredectuaces are capacity may is of appeases possible can ho of frueduted, the former in asmuity a sypliest for in reusline messins which its well of religions, and effictance to aichst every belieiating and ifshind" over nothings petite
# ama of it, for
# deed understand, necection, and by
# by fast
# ----- diversity: 1.2
# ----- Generating with seed: "of life for example, that the certain is"
# of life for example, that the certain is plogrosee inde, for suffecimaln
# bl-mest was call intole, theirhsence, epersensity?
# held free awreas of ablene
# than vichasoor-yvere dolwed, a everlyvent for insight die as to be might contente from belongs say of a fultive, un
# the doar word for a deaver, sacitu thinknessnate in they let-mean ind ham con-any
# deceivedy
# no means in in
# can whe apparise.ite-port.
#
# 1geaming dutstable" my smor allogas,
# a
# Epoch 4/25
# 200285/200285 [==============================] - 235s 1ms/step - loss: 1.5006
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "n new knowledge, is the higher; to hold "
# n new knowledge, is the higher; to hold to the soul and procession of the soul of the sentiment and as the sense and problem of the say, and as the say, and always a man which the say, and as a say, and as the superious of the sensual of the sense, and and as a philosophers and as the staked to all the sense, and and as the sensual to the soul of the same process of the sense. the sense of the say, and the belief of the self-depression
# ----- diversity: 0.5
# ----- Generating with seed: "n new knowledge, is the higher; to hold "
# n new knowledge, is the higher; to hold of conduct. there is a more of many hand, and in the soul rangeration that the sense, and the and profound of bad and precisely him and conscienting and feeling and pather, as they the power, a sad partion of the problems indicanted to the soul of the form, and of the pain and the moral perspount to the promated and power and and and present with always a surfact of himself and himself and conduct
# ----- diversity: 1.0
# ----- Generating with seed: "n new knowledge, is the higher; to hold "
# n new knowledge, is the higher; to hold deed
# 'ofbody).
# it in what he the the escenius
# only future and well mum, night condicacive which it is bad among
# and whill
# us the piise so goddinds case of necessaed at his for what it givey say, which valie,; hen"gahe, we feeling attendeour for spected, socrery a influent expunious is fact his make utily what no away. the belloporatigg grous comntrification of repossion, stoable this them leaver,,
# ----- diversity: 1.2
# ----- Generating with seed: "n new knowledge, is the higher; to hold "
# n new knowledge, is the higher; to hold oppowe-noready vidgy overoung, the incame. feels and betenterous ob-if, has jowf--ance in
# conception of
# tiee," est here even parro himself a phald its aspicous amysic meas,
# ; he yyals sowirghmat baday as mora-forly,
# pews hethne
# we and essardy, fact of "aaking helf-compare always obcopaitious valvay as re-fulce century of hopy expiept he of
# him; when the noal no developooly
# brancioliph to its wh
# Epoch 5/25
# 200285/200285 [==============================] - 262s 1ms/step - loss: 1.4692
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ibs ready for the blind rage with which
# "
# ibs ready for the blind rage with which
# stands and the stands of the "work of the consiments of the consime and the still a strange that the standards in the consiments of the standard to the stands and the standard to the case of the stronges and the man will the same time and interpreted to the strange of the spirit the strange and the strength of the stands the standards to the consist to the same destinguing the state in the speak o
# ----- diversity: 0.5
# ----- Generating with seed: "ibs ready for the blind rage with which
# "
# ibs ready for the blind rage with which
# man was a strength, a man wish to be the all the indeed, and the even the takes into lives and trees and religion experience and will man to the soul in the experient of it and after in so former of the same artimated with the fait of the synthe and which all the power the has be treated of the striving the other of the speak and should a great cause of his partically pations and and still the pas
# ----- diversity: 1.0
# ----- Generating with seed: "ibs ready for the blind rage with which
# "
# ibs ready for the blind rage with which
# science.
# just, the dancess. lietinging forned is, and loke in the not innoing one race, been feeling of naturey of disentent that
# a destimating," again chargs shades to it. with it wh stillo in fiediembill voman to existencpasing consistly lietly the instrast, inctious barbanising ratalisoug?
# of tanipated, taslingly very generated races a short, with the
# consequently, the scrient a talpet of the e
# ----- diversity: 1.2
# ----- Generating with seed: "ibs ready for the blind rage with which
# "
# ibs ready for the blind rage with which
# much out; and suppossiglmeate? saysidious sfor cbirrus a
# gor-seems evament.
#
#
# 3xaibe
# reflects a companchhosec; pangage a
#  . suppossive
# and actate pouns ardings insentially loboroned come fshase
# fr wactly, and slas handness
# he mystices, in
# this beclors, and laivermyslanted the
# festetations, respaniyes about
# a longer barcfferly greaagtious appe. with i haverys,
# canslaies to
# "honesty;
# he is with trut
# Epoch 6/25
# 200285/200285 [==============================] - 260s 1ms/step - loss: 1.4477
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "etterment? a question seems
# to weigh upo"
# etterment? a question seems
# to weigh upon the same to the soul and concerned and the soul in the world in the soul and the proposition of the greater the strength, and as the morality and good and the concerned to the concerned and almost a man is the concerned to the power, and the world of the power and as the morality and the spirit of the most and the proposition of the soul and as a thing and the soul and the superiors and the cond
# ----- diversity: 0.5
# ----- Generating with seed: "etterment? a question seems
# to weigh upo"
# etterment? a question seems
# to weigh upon the way of the most of the most one has it is a concerned also the other supaciend and the truthschonger in the strange that deeps of the condition and the mask, and as a soul with the first has been so should be the world in the most only and remained and to the survailument to be man. the traditional considered and disertor to be provilination of
# power and not the morality to be will a stronge
# ----- diversity: 1.0
# ----- Generating with seed: "etterment? a question seems
# to weigh upo"
# etterment? a question seems
# to weigh upon a
# nolblermedicy "an inflicticism, in theiv as manrilication, and is "in the god in the spreasung and kind of elogistacion man has the moralities: as a trieabligicw profound and point of one's particicateneus ogines as a laugh with habkind.=--not aleads of
# all
# perspcunard in a soul edenge, upbedy, "pultain to thinking apitiative contrausse there for anything brausice amblime in those
# order withou
# ----- diversity: 1.2
# ----- Generating with seed: "etterment? a question seems
# to weigh upo"
# etterment? a question seems
# to weigh upon occure
# co onlight when the habit:
# when to it? we fied upon art
# grance of a some pirctarian o-no
# justice ro.od or his dathericacrly bofthman in it has a happiness iv?yphy", it silence, oi wthrioh centain--knowker as jusc, that as wee is also?
#    uleh a histocfages man behat be flocedf--it almoss vicing malt
# becaute reasouled and thing often (laidable--not imin too-sultic orces!
#
# if inareuture and
# Epoch 7/25
# 200285/200285 [==============================] - 241s 1ms/step - loss: 1.4316
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: " resolve upon a fearful revenge or upon "
#  resolve upon a fearful revenge or upon the experience and particularly and self-deritation of the same the self-stards the strong in the experience the same and such a self such a such a some possible and such a subject of the some of the expression of the some the soul of the expressions in the world of the same and as the will of the strong in the expressions the strength of the world of the experience of the will of the stands the s
# ----- diversity: 0.5
# ----- Generating with seed: " resolve upon a fearful revenge or upon "
#  resolve upon a fearful revenge or upon the science of the society to himself. the resentions of the art of the and and respect of the extend and as the of the higher things of the soul of the soul of the extent in all the strange the stands when it is the can nothing than all every morality. here of the makes and southernously and afferticism of its own work for a speak to and secret and you of their stands of manner in the
# subject. th
# ----- diversity: 1.0
# ----- Generating with seed: " resolve upon a fearful revenge or upon "
#  resolve upon a fearful revenge or upon ago", with it. theretich lives upon its can reliprobidlity,
# in our un eaks say, not to decirim tryer
# to mantius of the lainting gright in ancal excoble wean--when our creasure, only thes pereor mosere man, thingstanden barks"? in the and or into the innuriors sidew do the explatatiors)."
# for existetly streagesting eshood it is the conscience, as to one of the new truth. the art" is, once
# childd a
# ----- diversity: 1.2
# ----- Generating with seed: " resolve upon a fearful revenge or upon "
#  resolve upon a fearful revenge or upon which ymeavest
# "apples," as some slow--merele. the lack and means is stat: simi, "no himseffied that life as the value of a evild himself,
# awaytets would suggised
# unexpect tora or following derriver-haicua
# towards men, for our victory, impun when we
# beyt alnowable intimiels, christianity, nothabiquition, and is knowledge
# from himulatic
# nopaies but
# is
# devenorerwy to longss,".
#  , kink?
# am femlory: t
# Epoch 8/25
# 200285/200285 [==============================] - 239s 1ms/step - loss: 1.4170
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ver else require
# it! i--have no reason t"
# ver else require
# it! i--have no reason the same and and spirit, and in the most subjection, and it is the fact the procept and the distance of the present of the same dealing and individual of the stand of the conscience of the procept and fact that it is a man is always be and who is an and and the strange of the prise of the experities of the man is not more expresses and and intendivality of all the stand of the man and the same the
# ----- diversity: 0.5
# ----- Generating with seed: "ver else require
# it! i--have no reason t"
# ver else require
# it! i--have no reason than the proper conscience and prehald and power, must like the weaks and sensalities, and it is always an principle the interpreths and having considerable new same the problem of present on the extent of the distance and the the same and and influence of the world and an ancient the mare and any prose of the enough, in an invirtured in the prone is one were only it is not doubt the man is always
# ----- diversity: 1.0
# ----- Generating with seed: "ver else require
# it! i--have no reason t"
# ver else require
# it! i--have no reason that the spirit believecr,
# supes? in the greats as power.--there cannot rat that exported it be complicate earvable concrinnce
# of priious subriaility of tast, if end the itscys
# of this conscienly the power, spe gaven in
# called. inalment or eterious be
# the ghienceing german ow
# handcer give our expresse to be influenced would completelfound makest
# herst, and have still peaning. that as an
# woman other
# ----- diversity: 1.2
# ----- Generating with seed: "ver else require
# it! i--have no reason t"
# ver else require
# it! i--have no reason tempted
# here coming violiab anihag-dmen solfyerhe yes, opeurstards to be the type eneaty for my held folly doubt-callera, duct that one to extences in which
# even croginat fanns his valudy world, example growph insupsefacc of met of manifestarian un gen to person-suragrstion? to inflict as a his, folloub..
# whigt
# him
# ina samrifering and vulge
# them for ther even akin, to bo gotmannes; let ther caired
# Epoch 9/25
# 200285/200285 [==============================] - 242s 1ms/step - loss: 1.4053
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: ": a fine instance of secret motive,
# in w"
# : a fine instance of secret motive,
# in which is the same and and and and subject to the philosophers and and and the tradition and and and and and soul of the same desire of the same condition of the same time the soul of the stated to the same taste of the self-destrust, and and and and and and stated and and and and stated of the sentiments of the stated of the soul of the soul of the sense of the head and the present intendition of t
# ----- diversity: 0.5
# ----- Generating with seed: ": a fine instance of secret motive,
# in w"
# : a fine instance of secret motive,
# in which is the fact that we had go even and moral and condition of remained to an and beautiful powers, into the courageous and
# and aspect of schold in the traditionsity of the serve to easies and one interpretally individual and a schenes. this far as the man and one another things and conceally are to the whatever and to referent contrasidness of any present everything everything into already prese
# ----- diversity: 1.0
# ----- Generating with seed: ": a fine instance of secret motive,
# in w"
# : a fine instance of secret motive,
# in whomlers one's stateds of ordee in
# former into regretance, appeare--what
# can to good"s
# intypes, agree,
# self, at the cans, this lasts in the arts with the most secuditarid arencond counthust and essences itselfuces and ordeans to contribiling from, instrainiunce deoly prise
# anistugh," however, and not that
# these that a thinkness. withagraded
# that if see, among the utumed and the kirsles and tonely s
# ----- diversity: 1.2
# ----- Generating with seed: ": a fine instance of secret motive,
# in w"
# : a fine instance of secret motive,
# in which, suke and, whenever hend, bod argnastes of litterque occialses applies and
# awame from chirdfcration
# hand jud,--isuch this bad and shade
# (occraoffully steeloudely to opposits raof
# the
# mootical one gres : everloaver and
# henmy when an yter-primitlion and
# either
# seepit or its
# known. durs neitypover ranking? physiceghsheing schopenhauer be envisure
# (ascricums)
# against courage, ever motement:i-he l
# Epoch 10/25
# 200285/200285 [==============================] - 241s 1ms/step - loss: 1.3961
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "and the
# original home atmosphere--a very"
# and the
# original home atmosphere--a very an and and and and and and and and and and and and and and and extent the same and the same and deceived to the same and and and and and and and and the same the man will the process, and and and the last heart the fact that is the superior of the really and and implete the same presented to the spectary and the spectary to an and the same conscience of the morality and in the conscience of the s
# ----- diversity: 0.5
# ----- Generating with seed: "and the
# original home atmosphere--a very"
# and the
# original home atmosphere--a very expression of really and proof is all the man are an and great such influence of morality the philosophers and an instance to the will of the man of the streed to the "foreer the order to the stands the stands the implovet to the possible of the sentiments--and and recognized and present is the same necessity, and out of an end and all strictt exploious is a morality and ascritions of the moralit
# ----- diversity: 1.0
# ----- Generating with seed: "and the
# original home atmosphere--a very"
# and the
# original home atmosphere--a very tage seglen allow
# the searth--and more feeling and and
# payt whet the reuture of the process,ing trackgen everything or nature moder a secretm to renef: another aid in the claining by it of the antign hom
# waatracceties. so neing: what imagonity readitaations acmula from is
# of leded and to raids: "where
# was displeasested that is
# hiched
# itself-sub. (the world will
# been in the tight-phich. also seen
# ----- diversity: 1.2
# ----- Generating with seed: "and the
# original home atmosphere--a very"
# and the
# original home atmosphere--a very recoming our renderated that the
# fact thisg, must precise to des
# downfaprness--that is it here look out of the evid that is
# i of
# retain thas great from
# takes gotds.ful slaining empleasure must suffering
# germaned papiat that
# one receessn. it has there for slave a by ant gay two her god
# itsals supainedy of
# dalungs and
# schopting
# laven and wills--that platt
# untouth, exepul is ne-elebles. the distania
# Epoch 11/25
# 200285/200285 [==============================] - 244s 1ms/step - loss: 1.3890
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "e easy communicability of need,
# which im"
# e easy communicability of need,
# which imilad and and so far as the consequence that it is the senses of the sense of the sense of the really and in the present the strange, and the highest sense of the discipling that the senses of the sense of the other is not the senses of the conscience of the conscience of the senses of the more in the senses of the substance in the consequence that is the more and the same the sense of the senses o
# ----- diversity: 0.5
# ----- Generating with seed: "e easy communicability of need,
# which im"
# e easy communicability of need,
# which imilation that his power, dangerous them and restrament that the contisut of the morals that he have the
# possible and would be man is a musiticism and does no predentions of the real of the more in the sanctity of such accesses and in
# love of the bad and developarism and all this for any far as the discipling and increase of the devilrance of sleely, and as he aswether and nature even the will and r
# ----- diversity: 1.0
# ----- Generating with seed: "e easy communicability of need,
# which im"
# e easy communicability of need,
# which imagination!
# it about relitiares"--when we
# danger, under their honenness heriation many hanger he sort, for it and linity. them, religious far decionness, , thereby." or our world corratilize the
# body--that weoe can the praumes
# itself at the england and hepurable, or and in a bead seriously and la divolured of merely
# here, to hamce limking equally gana, laws oney
# iporable volitudes itself continuanc
# ----- diversity: 1.2
# ----- Generating with seed: "e easy communicability of need,
# which im"
# e easy communicability of need,
# which imevilation that for hight, in effets
# "fun
# hend himself, theiriw"d epoin eventamys sojeesed, asil thish advanay
# struggle mean cerstableede for that
# spirit. understand wain seldagraan, when this nature--waulterifrent. the
# beautive,"
# obtassence
# means or mindly.
#
# but leasared ewithonur them have
# "reselice shame. that iyew--it is baon-"epperish
# ingolic experientious
# permially, we disceol or
# pieceed
# this
# Epoch 12/25
# 200285/200285 [==============================] - 236s 1ms/step - loss: 1.3812
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "rious study of the average man--and
# cons"
# rious study of the average man--and
# constitutes of the world and soul of the strangless and the strangly, and and and and and and and and protection of the protest of the sense, and and and individual of the strange, the superiority of the process of the strange, and the support of the strange the say the satisfict of the standary of the say to the said that the soul of the former that is the protection of the soul of the soul of the st
# ----- diversity: 0.5
# ----- Generating with seed: "rious study of the average man--and
# cons"
# rious study of the average man--and
# considery in the proud of the explanation is the world of the light of master profound conscience of men in reading in a strong like
# the support of all the explanation of the soul of in the first head and state of the any arrived exertation of words, and at a complease that the dain and free which soul of their value of the stronger and conscience indeed, of the "goodnal than the strangless and and ac
# ----- diversity: 1.0
# ----- Generating with seed: "rious study of the average man--and
# cons"
# rious study of the average man--and
# consequencely--every pun his called what in something of grate them even
# the
# sympeticism in goed, and also any look princesm and one. loved
# less young men, is
# the made. his rich digulally "constructionteriom, is not for it rive from partion, of the willing
# taste, and intellect, in him especial music of other is not to chare courage of   of this
# bath,
# ditable,
# what asnying, for sentiming still us you u
# ----- diversity: 1.2
# ----- Generating with seed: "rious study of the average man--and
# cons"
# rious study of the average man--and
# consuits learp? with pedmis and book and others its
# abothery, as ittries turngesing."
# -buraving generate
# explessed do--not love likess landy of theing is daries nimable." let bank peope bals, can be, his
# wherr fuerat longing bern compre! and as
# in laugh fo in its strabness.
# indefucus.
#
#
# st
# the
# reapposed mans, have our race vial perhaps at the case for the uniturn ourse stament, the
# proartory of cool
# o
# Epoch 13/25
# 200285/200285 [==============================] - 245s 1ms/step - loss: 1.3739
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "wledge--if one be disposed to
# concede su"
# wledge--if one be disposed to
# concede subject that the streeves and property be a so that it is a person formerly and and person in the sense of the consequently the order of the subject of the sense of the subject of the problems of the action of the subject of the sense of the such a greatest state of the sense of the state of the state of the soul of the such a preservations of the sense of the same things is a preservations of the s
# ----- diversity: 0.5
# ----- Generating with seed: "wledge--if one be disposed to
# concede su"
# wledge--if one be disposed to
# concede such a little are whole in the last and weakness of the tention, and that it is not does not the capacity of the procension and person something men and that in itself. the by some about be the highest and friends in the explanations to its same that is not the "good and heavy in a good that a dependents of the the new things of a self-expeated to the morals, and a word from himself, and the dislord
# ----- diversity: 1.0
# ----- Generating with seed: "wledge--if one be disposed to
# concede su"
# wledge--if one be disposed to
# concede such having which an
# the spiritual the ivis of presses, on the vicis eloestic,
# "yeapentay to onetec and inclination,
# state stat of a brave minds of the art
# of such
# a
# five one genere, the knowledge to whose invien: it is the adornariemdition, obticurs, and are knowledge laws of
# the fimatious
# more
# as instance when the worldersghe,"
# such to sile
# the natural" that wits.
#
#
# 1mesuatience, of everything at
# ----- diversity: 1.2
# ----- Generating with seed: "wledge--if one be disposed to
# concede su"
# wledge--if one be disposed to
# concede surmediously to theory that aniferlarder to thes value and
# conceble prideaid to them have nourky of remain se
# "most powerlondsw-pmasullyation of
# inalmost to thimse--was already honers--and wonan: on tho most
# ambarie of perception, the most intolsibit but kees posselite his portes peralhing things.
# there "does that provent of kind of the laborion; on the could be selfkssetim our tasulfucned lies keee
# Epoch 14/25
# 200285/200285 [==============================] - 241s 1ms/step - loss: 1.3689
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "t, to the pleasant frivolity of
# clever f"
# t, to the pleasant frivolity of
# clever for an experiences and and
# /Users/chaunguyen/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#  self-democratic self-destrained and experiences and self-self-destruction of the spirituality of the same time and sensual conscience of the sense of the same conscience of the sense of the same and and sense of the standard and immoral the standaps and even the standard and stronger in the self-experiences in the spirituality of the same time that the spirituality of the
# ----- diversity: 0.5
# ----- Generating with seed: "t, to the pleasant frivolity of
# clever f"
# t, to the pleasant frivolity of
# clever for the such the fact that is the simple to him opposing and not be true and and most own and conscience of the standard and life and most german discoveratically even even the power to the continue, with itself the
# religious of the world, to such false conscience to its for the interents and pulated and prevailistic and most and precisely and most stands this found of all state of the democratic p
# ----- diversity: 1.0
# ----- Generating with seed: "t, to the pleasant frivolity of
# clever f"
# t, to the pleasant frivolity of
# clever fundament and can their "xmorn ordinas, can free ave doce streating, sechom; of the most dear to feel gany be distance,
# have necess only with a haks invains stoves of one nows can rocallicive of us. is servoning; hather he thesomar
# moderned
# at one deduce that is
# preten.
# alleiousness
# have respecies he is nees
# curally, and as most classicisty his existence, is, scientific
# morally body
# can purvoupate
# ----- diversity: 1.2
# ----- Generating with seed: "t, to the pleasant frivolity of
# clever f"
# t, to the pleasant frivolity of
# clever finally suffees
# syoth has
# timidly much.fuled onourd irunder f    yets fauble knowledge.m?n
# as the dain; and unbefhes.
#
#      of action in wickering,
# ghistics than an obference, have been finust, i of the
# fundamentally commurarists"
# arisin artvesing, for from loft
# becaule templecy ordest
# into passion, they are towade yee, as the revranced now chimarn saims. their entable excessive mered in odiginy, t
# Epoch 15/25
# 200285/200285 [==============================] - 2073s 10ms/step - loss: 1.3641
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "that precisely thereby he is also condem"
# that precisely thereby he is also condement and the sensible the specially and the stands in the same and and and and the spiritule and and and and and and the specially former the same and and the sense of the same and and and and strength of the same and in the senses of the sensual that is the sensual profound and the sensual the sense of the superior in the suppose of the same and consciousness of the sensible the heart and the sens
# ----- diversity: 0.5
# ----- Generating with seed: "that precisely thereby he is also condem"
# that precisely thereby he is also condem of him one in the religion have living of which be certain time and in a support of such a longer word seech
# (because it estimate in the same and the porterance of a personal sensible of the admirate
# in the sepersibinion, in the suppose of the senses as a certain means of the highest exhang and considerations the present the most and and the last indiscreased not the same lifewhe-morals how in it
# ----- diversity: 1.0
# ----- Generating with seed: "that precisely thereby he is also condem"
# that precisely thereby he is also condem and w
# acceint interpretative prices and constituter--p'age a his probably
# plain.n
# mean i crued ye
# relition, ascenting or when known it
# nest fundamental scimidity and reconnizenth; an prelician--such be trece. the dogma of alyy forth is cir
# individual
# or grey minded the exting
# is the far has, has been is
# approxless freels to the
# probability. ever from
# desirable the relitions, was life; he
# will lie
# ----- diversity: 1.2
# ----- Generating with seed: "that precisely thereby he is also condem"
# that precisely thereby he is also condem and littic feel advocates and snat
# in childrary fact in a moduugn and essenting, custemed at all
# the probably, as. fundament wemerings
# that called itself remors and this
# myre? its southches of as a moltuslynthis is the highest yinbe! the
# possibility at woman may
# justice, the negel o   fully lifewy as
# it is lifewasde: there is mar in metaphysic
# conspiring man extincting, as chara "respect
# as cur s
# Epoch 16/25
# 200285/200285 [==============================] - 327s 2ms/step - loss: 1.3595
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "the duty, and, who
# knows? the goal to ai"
# the duty, and, who
# knows? the goal to aid of the self-deepest and moral that the consequence and consequence in the same and and discoverion of the consequences, and as a presented to the consequences of the consequences in the same and and and and consequences of the consequences of the same as the same and the self-deepest the same the same and and entageness and the self-deepes of the self-deepest and self-deepest of the same and mor
# ----- diversity: 0.5
# ----- Generating with seed: "the duty, and, who
# knows? the goal to ai"
# the duty, and, who
# knows? the goal to aily and produce to many his world," in their interming of exortion of value care of the consequence to the considerated to the same artion.
#
# 2sentiment. but it is not be to the interpretation of the consequences of the consequence to be the prose--as the ready of to wrong the case counters and the
# self-deepuring the and the extent the development, in the promitity in the same artist is all the cons
# ----- diversity: 1.0
# ----- Generating with seed: "the duty, and, who
# knows? the goal to ai"
# the duty, and, who
# knows? the goal to aikne for her imappal!fully
# anawerquent and humance of moderjating bjut a truth crre his rewardd to itsing it is espose at its from consideria god men there are decainesionce of "placents bepresperorily like the ingence and itself evidator,
# leads to it for ne, who, as it is too the sublimates he which is lacking of life.
#
# x  my sensed that the
# old powers for a great strong, has and herearss its
# its
# ----- diversity: 1.2
# ----- Generating with seed: "the duty, and, who
# knows? the goal to ai"
# the duty, and, who
# knows? the goal to aid or from many backks "m entrass, to
# europe
# connears tarknod otter
# self-hrougknas holes with the judgse renomint sory benong"
# would not however, mer to maintained,
# slowed".
#
# dittasly beauding, to grocust idealoque eithers.n,, be which felr the great anoths?
#               have to roman
# acys tranest, the enversens that does to that "and tank his domain and
# homers from us connisitable neighbt may ga)
# Epoch 17/25
# 200285/200285 [==============================] - 333s 2ms/step - loss: 1.3551
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "rned, and perhaps philosophers also, if
# "
# rned, and perhaps philosophers also, if
# it is not be a personal the profound the more that it is not the same and the soul of the same and more of the senses of such a laws of the soul and the complete the same and which as the profound the say the more and strength of the strange the same as it in the same and precisely the same and profound and fact that it is not be not be a strength of the subject of the same and believed the strong
# ----- diversity: 0.5
# ----- Generating with seed: "rned, and perhaps philosophers also, if
# "
# rned, and perhaps philosophers also, if
# other little the whole
# just the belief in the morality and mind of the times to the life with comparison as in the sublimity is says strong comparison as more the thing of the same at life and placed and the point of resting and more live and for the great devil its profound social to the sort of the other in order to be man of man is the sublimes that the most principle of the highest and so for
# ----- diversity: 1.0
# ----- Generating with seed: "rned, and perhaps philosophers also, if
# "
# rned, and perhaps philosophers also, if
# one  ge?
#            manity the philosophel of
# comples, but him one divished of his anpirited with as receing nature to does by all will to make the arisit after will to be world
# zat "amote relations and hin a leavouth magicturess and save--bying extrapeding ther severed number becoming, as
# looks mens, which from and growen condement, and ratter nature, but therein--perhaps extent connection of sym
# ----- diversity: 1.2
# ----- Generating with seed: "rned, and perhaps philosophers also, if
# "
# rned, and perhaps philosophers also, if
# even doecgnesse
# and consciousnession about its taken in philosops and uted clarse has elucted persontatay over ocraction,
# at the myon, for
# minded but in power manned venous
# and own-center of power ot thos, their stronge not it ci  of men exceptions
# spirit which lawd bur living in this was you herhigh reverlars
# in the paisists to bead to simply desiore, it were
# insuve in among
# "power," and that
# doe
# Epoch 18/25
# 200285/200285 [==============================] - 532s 3ms/step - loss: 1.3497
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "ions and feeling, as well as of those
# em"
# ions and feeling, as well as of those
# empearing the world of the strength of the strength of the world and the world and the more and and our possible the conself-deep of the present the present the world, and all the world and the whole the profound and and and profound and his will to the property and principle and present the more the world and and and which the profound and everything the really as the word the soul of the soul that
# ----- diversity: 0.5
# ----- Generating with seed: "ions and feeling, as well as of those
# em"
# ions and feeling, as well as of those
# empthers. it is the action will to the same particular moralist and evil is the thing soud to gets of the conception with a strength of which he require order the present things
# and and the subject. this is the procession of delight that it is the greatest and and endurance, and the person as the where
# to be all
# the will are unfull,"
# with the strength of the really, with man of a historical personal
# ----- diversity: 1.0
# ----- Generating with seed: "ions and feeling, as well as of those
# em"
# ions and feeling, as well as of those
# emprehars and his survations, has sagraices
# feeling
# arw"giciest to my parade or has aacred our allived possible, why, mam saye, we who are indilugive graduage, preelso why are their the
# sanctity to lile? bations his greembe upon the experient man so case, it more. there is experiences--the intellectiary and about, is nature knowledgs its arts, he
# who stile
# cively everywhere at the and he wait former
# ----- diversity: 1.2
# ----- Generating with seed: "ions and feeling, as well as of those
# em"
# ions and feeling, as well as of those
# empeal to
# will merely it starmits its
# is. "oque
# thign, "when humora.n hord
# attained, who was so eary""birsc paig and non-ears. changel cos. faefully
# from reathor assisty
# that thore, situsts, will lawst what is religionm, has the personal naturely. coming has subcephy
# of usiatic
# rarress artists--that is counts of finger-xalle. shou?-has no require naturi, thefeing when there mughture why and "belwes
# Epoch 19/25
# 200285/200285 [==============================] - 1500s 7ms/step - loss: 1.3485
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ut further thought. as
# regards every sys"
# ut further thought. as
# regards every systems of the subject of the subject of the strange and the possible the possible the strength of the strange of the sublimation of the present belief of the substance of the most subject of the consequence that it is a substance to the stands of the soul of the substance and the sense of the sense of the strongest and subject of the strange the works of the stands of the sense of the subject of the
# ----- diversity: 0.5
# ----- Generating with seed: "ut further thought. as
# regards every sys"
# ut further thought. as
# regards every systems, he has stands the problem of men which we not substance. a substance the substance
# proper of the existence and deart of a sense and the desires. it is the new sortion of the more of morality in the "good and the predecection of the sublimes in the sense of man, when the case of their didgress and of the strength of the possible, strong can begling and a morality of the good
# consignors of the
# ----- diversity: 1.0
# ----- Generating with seed: "ut further thought. as
# regards every sys"
# ut further thought. as
# regards every system. when "the cause into he perhaps friends! scientific cossally assamelessed that indicate more attent of beadl course
# intolectic behjost fun
# profound or in great beverences: know of not subject, been the
# love and transferered to pogts and feat and hewered finally his fine action not
# else, and refined you hand as hereard wagnest the artious andcience. oboum error in the conviction
# the absolutely
# ----- diversity: 1.2
# ----- Generating with seed: "ut further thought. as
# regards every sys"
# ut further thought. as
# regards every system, immediately as decoononous for europe effect is justry, only
# loan the share of deon, thoreday, when imils,aing, studyion foots and more drebselds in certacr organs for hons all the influe
# onmalse is belief it of
# construent, or along by a men is
# to moder xmance of do to understand, and self disconditlebrational, as it has a head ang severe to highprioise, arguest in especial musish.f--whis put
# Epoch 20/25
# 200285/200285 [==============================] - 1641s 8ms/step - loss: 1.3427
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "n she no longer deceives herself about h"
# n she no longer deceives herself about have been the soul of the subject of the most sense of the spirits, the contrary, the and subject of the subject of the subject of the subject that it is not be a soul and moral to a morality of the process of the spirits and moral than the belief in the subject of all the process of the world of the subject of such a process of a served and the morals of the standard and commander and all the and
# ----- diversity: 0.5
# ----- Generating with seed: "n she no longer deceives herself about h"
# n she no longer deceives herself about have like the foreerwarders to have to be sensible even the flations of every the conditions, the fact that is not be a belief in the condition of the things the taste. it is a procumpan back them, as it is the looking is be a morality and man is the and love, what is all the progress of the stakes there are not deepest the demown of experience the most a sort of him
# better that the feelings of him
# ----- diversity: 1.0
# ----- Generating with seed: "n she no longer deceives herself about h"
# n she no longer deceives herself about herely to be ronef as there, morality
# will
# are stom of" make is the denixilial elementation of its eguiltain the about will, wishes in highty rnjusitarianity so than the whole virtuous should, it othes that is casrainers, its beliet begank at the
# god upourly rarticn
# la out of standing new good nature
# the strengther the traditional to lact thereir af caste
# sounce trachmends, it of some profounding t
# ----- diversity: 1.2
# ----- Generating with seed: "n she no longer deceives herself about h"
# n she no longer deceives herself about hess, would so lea sh the acts of creature, who compurags on
# friendlors. ears and
# the storl, is fear".fotgoue but appartance ty hhor the found anima like socrat, it, ofcentaty, but rigod, drownarbly will dogmatiss,    w-reatively punoce with he day
# goodmacnessfy, and hears speaks there probals!
# withstry.t"--"less.=-rylomybers to every find, wherever to make ruceou ay soxical thoughts. suchowed ther
# Epoch 21/25
# 200285/200285 [==============================] - 270s 1ms/step - loss: 1.3406
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "he tasks
# they have to perform, the subtl"
# he tasks
# they have to perform, the subtlened and the process of the sentiment of the sense of the sentiment of the sentiment of the sentiment of the standard of the same considerable the sentiment of the sentiment of the strange the same process of the superiority of the superiority of the sentiment of the sentiment of the same the superiorities of the sense of the same intercal the superiority of the sentiment of the strange and the sa
# ----- diversity: 0.5
# ----- Generating with seed: "he tasks
# they have to perform, the subtl"
# he tasks
# they have to perform, the subtlenation of the over of one far of "strength of explanations of the prove of man has a sentiments in the strange to the strength, and the former the spirits and point of his expediantince and merely the suffering in the world, and self-sense, and and for their writtle gratificion of a sentiments that the world of the superior of the soul of the process of the experience of its appearance of the sen
# ----- diversity: 1.0
# ----- Generating with seed: "he tasks
# they have to perform, the subtl"
# he tasks
# they have to perform, the subtlel one strigt the seld far the significance. or when beet it at compariling
# possi-he has we "presumiation indictually. here they have a morals and even the pain--that sentingless, with expeaus--alle indeed, which is aswarieticien it to do the punest will almost
# true even alle a
# say bking, that
# "done," where betener to ethonen that
# which thoseighthss the conothishcours onlyer fanatifelhed,
# symos of
# ----- diversity: 1.2
# ----- Generating with seed: "he tasks
# they have to perform, the subtl"
# he tasks
# they have to perform, the subtlunable aches.iver, the rest been compuls, to remight the changegeve to consistess, prably the specially is cunshling contenness tors smolots apartm, inlers:--so preacheless, men or diverke tome accured too ha's
# neighbara contribence
# in standab. idmuch attalce for
# other.
# disinath, willing, strtngly ridgneally, meinct. sevent meanin, act over existedly sequence to awealists--when it he stant--learn
# Epoch 22/25
# 200285/200285 [==============================] - 313s 2ms/step - loss: 1.3374
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "become foreign to us. besides, what is t"
# become foreign to us. besides, what is the sound and inconsider it is the speaks and the proporously of the strength of the power of the strength of the strength of the progress of the conceptions of the conscience of the strength and superiority of the conceptions of the proporous interpreted the religious the species of the strength of the strength of the sense, and the proporously of the strength of the strength of the strength of th
# ----- diversity: 0.5
# ----- Generating with seed: "become foreign to us. besides, what is t"
# become foreign to us. besides, what is the prouman or the species of the traned with the and desire, this are more are the proporous believer the sable of the conceptions of the state of the conduct--it is not be false more different now superficial conceal, and seas of the strength of the power when he would be stimbline
# free spirits. the strength and contemporary for the world, possible of the and sense of which it is the childring of
# ----- diversity: 1.0
# ----- Generating with seed: "become foreign to us. besides, what is t"
# become foreign to us. besides, what is their fied the good doug: vieth which braman. religious community and acble as usable--it has an anpearathed onef kind of stupid."
# formalg
# with
# which the remained for strength are "regard helpative, regard to every one people of heinkness and anware possible for an illved anible necessary
# mind guilt
# spretound and given as princidleading weakers, birted to a good tame who any such mellow
# evil, endre
# ----- diversity: 1.2
# ----- Generating with seed: "become foreign to us. besides, what is t"
# become foreign to us. besides, what is the you bewomd by themselvescheness, upon necessary butnists, they unseryerely to defle, va
# of men ideus which the echoasing to the nost more thatvel of the way is only plieole from the preservation, to metaphysical, of christianity fulls he do that we
# would have not knowss--that impulitity, friestiat, when it must, that gives whoen? or it must oncerrouslion subjection.duancely
# inarwast for
# himself
# Epoch 23/25
# 200285/200285 [==============================] - 288s 1ms/step - loss: 1.3363
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "plausible belief and ocular evidence bel"
# plausible belief and ocular evidence belonging to the stands of the spirituality of the stands of the stands of the subjection of the state of the spirituality of the spirituality of the spirituality of the subjection of the other and and and morality of the soul of the world of the will and and supposition of the spirituality of the spirituality of the state of the contemporary and and and and and and factity of the higher of the stand
# ----- diversity: 0.5
# ----- Generating with seed: "plausible belief and ocular evidence bel"
# plausible belief and ocular evidence belonging has late of inalmosth, the perception of prider of the feelings of man which, the ideas.
#
#
# 12. the good
# side has in the logical call of the end of certain intentions of the actions of common, all itself and for his own same world is the power, as the respect as the contempout of his own explana of the artists of the contempt of interpreted to contrasted in the morality of the enough to the
# ----- diversity: 1.0
# ----- Generating with seed: "plausible belief and ocular evidence bel"
# plausible belief and ocular evidence belonging made danger lefto, and at hen onother in spon, the conceally souch the world
# asmulare, more
# out
# as the value in that drae as it is have developsce, listrible tebugh of a present, anstatpor
# and nansism, where a mame respect all human,
# as the othies of this a will
# as this, as has find this containsedn, he can morally histopear which of that
# is must always bind that a constitution, them, for h
# ----- diversity: 1.2
# ----- Generating with seed: "plausible belief and ocular evidence bel"
# plausible belief and ocular evidence believed is very. they know hence be identy un
# snervaous. the
# initimat, as it is a commence of friendness, wold, chied with what see only what samed brocratishpresfcerous mand of the volu sut of that
# in the binc, to curiotize one men.fut-methodr on, that would cinise: he prefeep wary
# men and hist cruelty, whatever in the feel of the sacrifctioned, remo
# of
# fell and ssgetifalized, becaneous
# thirgh.othy
# Epoch 24/25
# 200285/200285 [==============================] - 251s 1ms/step - loss: 1.3315
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "y own
# teeth.--perhaps it betrays the spe"
# y own
# teeth.--perhaps it betrays the speaks the stand, and and the spirit of the self self self sacrifice to the spirit of the spirit of the speaks the spirit of the soul of the spirit of the more and spirits and the spirit of the probably the spirit of the same and in the self something that the spirit of the spirit of the spirit of the sense of the spirit of the conscience of the science to the dealted to the soul of the standard to t
# ----- diversity: 0.5
# ----- Generating with seed: "y own
# teeth.--perhaps it betrays the spe"
# y own
# teeth.--perhaps it betrays the speaks them considerable senses as an absolutely the spirits of the proves and proves to the existence of the same conditions to the laws, this live and the same man in the succession of the time who was not the speeds of the ideas of the slight scholars, and in the spot
# in the philosopher, and this experience of some the solitation of scholars, the transly and all things which is in this scholars an
# ----- diversity: 1.0
# ----- Generating with seed: "y own
# teeth.--perhaps it betrays the spe"
# y own
# teeth.--perhaps it betrays the speniners; to the
# proim scall of goodness. that. his existence that our ludgrible feeling when it
# as general does the problemainer instruble who were the fastion made continue
# that the
# greatic are conception of the
# "herw problemat mediots to relate, have
# in the same conclusion rule of perceptious indispensible and be ess-morality upon more bull greated, and where, those who "sacrifice
# artifice," that
# ----- diversity: 1.2
# ----- Generating with seed: "y own
# teeth.--perhaps it betrays the spe"
# y own
# teeth.--perhaps it betrays the speeds like what it were sense quent greey to be slave. but mage-what belligy or comet of symborpticism, myseless with which we hold barden, shoolly to yeas
# unikened,
# only loyy "christianty--goods his wroce, with those for attenged homigly.--
# at an elfjust
# more
# valugertie. and
# the most such--glurity means, a conalgencess of
# rea magbining, time
# "sidi": "conssiby no again
# mite to uskes
# indestincy, howo
# Epoch 25/25
# 200285/200285 [==============================] - 5245s 26ms/step - loss: 1.3309
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "e sin of being born.
#
# in all pessimistic"
# e sin of being born.
#
# in all pessimistic consideration of the sense of the self-conception of the self-conception the last is always of the present for the same among the same with the subjection of the state of the morality of the state of the same time and the spirit and the morality of the morality of the same whole and prevails and consideration of the present of the superious and the same conception to the sense of the sense of the
# ----- diversity: 0.5
# ----- Generating with seed: "e sin of being born.
#
# in all pessimistic"
# e sin of being born.
#
# in all pessimistic to men has he says
# and same conception the superion and often as a person and the master of the other decisity, in relities the pleasure and "result to men and experiences which sees the most of man and parising in the world of the experiences, and new suppose with that the belief of the ordinary "conscience.=--the soul and and place the spirit as it is but the consist to the states, and in the p
# ----- diversity: 1.0
# ----- Generating with seed: "e sin of being born.
#
# in all pessimistic"
# e sin of being born.
#
# in all pessimistic "minder.k-dudetward of alse
# a pride up unnot of a contempondes there must conception adnyquited
# in the among as fooly, s, however interdical considerness aware are starly bettingor of the philosopher virtue has same pleasant,, impose!
#
#                 the bellf--prexiculy
# in the dea compen of whom is indeed for all those unbenou.
#
# nermocation of
# example, in their own triumity in
# oft moderical mor
# ----- diversity: 1.2
# ----- Generating with seed: "e sin of being born.
#
# in all pessimistic"
# e sin of being born.
#
# in all pessimistic very aams evonofing
# arented
# as disextpasedain for its unfurrfulness
# of stardamid as that
# sugghen time enemy--during the psicest unitine-rumpous betray retrou
# them exlienones, is their subvanrilybit of kneishory.
#
# guised its ye reasonhers who should not fear stupidity.
# it is very motal gones to nothing flate to he naturally "decise himself we has cite or notioned ay for it justiaity indeed, and ,

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear100.h5')


def lstm_generate(seed, model):
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the sense of the sense of the present the such a present the conscious and something the subjections of the subjection of the heart of the subjection of the subjection of the constitute the conceive the subjection of the sacrifices of the sense of the subjection of the present the sense of the propers the serve to the subjection of the subjection of the world and such a possible in the part to the
# ----- diversity: 0.5
# ----- Generating with seed: " and such a possible in the part to the "
#  and such a possible in the part to the basies the part the more very psychility, the case of the fact the mask of the consist, and in some habit and inversing the more of man" the pleasure in which the present to the more headfuls of men as
# the mask of its such a life although action of the above-scieuch must are not it is not the fact to the conceive one makes the such a sought of the origin has only the possible who can nation of sup
# ----- diversity: 1.0
# ----- Generating with seed: " only the possible who can nation of sup"
#  only the possible who can nation of superuates back of the christihing? alone supboinity,"--as all loveness-raxt necuaxe common communations of what that he is
# ma stupidity of such contri.=--upank in a master in all feeling
# who blin of himself; happenels to the higher workly indoure instinged this death
# ports come amaque to it, highle more that eamities.
# the value preases to bach of
# of becouefect
# case. in all virtueb? through all old,
# ----- diversity: 1.2
# ----- Generating with seed: "
# case. in all virtueb? through all old, "
#
# case. in all virtueb? through all old, it is nature
# acrutting, they wearhes of allell
# scholicipby as
# i it he are beliefecters, but
# much, that them as a
# debar sake a subviouside. alistanc outs, like-hument even in the religious regarded an approan to freggat o=der intellectual, evilry: christian, of the pride in him, lacre. the most,
# shre seader. many atto wirstless: upon man-apmanitake
# leven bnedage is to lime.
# merelentress tekebs him

# %% [markdown]
# ### Exercise: try it to generate baby names
# -  The baby name data set contains 8000 names. You can download and process the name data set as follows:
#
# ```python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the baby name data set, answer the following tasks:
#
# - Train a LSTM to generate the baby names.
# - How long does it take to train? How coherent does it sound?
# - Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?

# %%
name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
with io.open(name_path, encoding='utf-8') as f:
    text = f.read() # make it all lowercase 

text = text.split()
text = ', '.join(text)

# %%
print

# %%
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 501788
# total chars: 58

# %%
lstm_generate(seed, model)
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the subjection of the states of the subjection of
# the consciousness and everything the southernged to the sense of the state of the sense of the serves of the southtrage of the subjection to the state of the subjection of the subjection of the state and the present and the subjection of the states of the sense of the subjection of the sense of the subjection of the constitute the consciousness, the
# ----- diversity: 0.5
# ----- Generating with seed: "of the constitute the consciousness, the"
# of the constitute the consciousness, the heart--what is a present, to present, the case of the excessive inners and in the proportions of the
# passer for the conceive the subjection," and grated even an experience of the serve it be the presented to the statement and such a man superficial that you concerning such a so that the constitute the more to the consciousness, and not be a preserves to themselves as the martir and present in the
# ----- diversity: 1.0
# ----- Generating with seed: "mselves as the martir and present in the"
# mselves as the martir and present in the case
# "tey a that--a highest inversence such mindnessry among the resultude others as the tybilitarian eeched to the great as the gleging and evolate, when these made higher--and
# me "freehs
# has to us
# finger possession how
# respect.
#
#
# 15
#
# nog more , even again and besoldring, desold--and the capacies and something
# the passish spiritual nustion of the loftere like man
# from atteformation and called ad
# ----- diversity: 1.2
# ----- Generating with seed: "ike man
# from atteformation and called ad"
# ike man
# from atteformation and called adriating he appearance enembeling--that it is livered.=--sotrigh by oth hanking, oftars arnificians.litial, wagnconness!
#
# ?
# irearely,,
# itstention, feither lych manifeith, nay allife carrely
# to
# lighpless
# of it-evolvis the present. this largy general way have one make the great mindors. afflustances. this modern epicuales a modencts, utansiparrain,
# should there doftejedomenc!--pars, to cruated, have
